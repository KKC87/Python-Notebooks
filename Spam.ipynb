# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib as pyplot
from sklearn import preprocessing;
from sklearn import model_selection;
from sklearn import linear_model;

# %%
df = pd.read_csv("mar.csv")

# %%
df.head()
# Out:
#         ctry_name intgrtd_mngmt_name intgrtd_operating_team_name  \
# 0           Japan              Japan                       Japan
# 1   United States      United States               North America
# 2           Japan              Japan                       Japan
# 3  United Kingdom                UKI                      Europe
# 4     Switzerland               DACH                      Europe
#
#             city              st      sec_lvl_domn  device_type  \
# 0    SHINJUKU-KU           TOKYO        DION.NE.JP  MOBILEPHONE
# 1         BOSTON   MASSACHUSETTS         MYVZW.COM  MOBILEPHONE
# 2    ITABASHI-KU           TOKYO      AU-NET.NE.JP  MOBILEPHONE
# 3  TOWER HAMLETS  GREATER LONDON  LYCAMOBILE.CO.UK  MOBILEPHONE
# 4        ZUERICH         ZUERICH            SAK.CH          NaN
#
#         operating_sys                                            ip_addr  \
# 0          IOS_12.1.4  c886b41b9eb35a337f4bad269694385abd7b3dbbfe1c0e...
# 1          IOS_12.1.4  6094e3c964ed82977d3fd21f329ef95a3797bc096bd057...
# 2           ANDROID_9  0be8b14314f2db7382341a9cbd4fa1ad3b4ead5d18abf7...
# 3         ANDROID_7.0  84336ea16262a7cc780a511cbb278a21a3cb21a6b3f5cf...
# 4  MICROSOFT_WINDOWS7  bb27df944b12d248b1cfbd505576ab516057e5e14bbe33...
#
#                                           user_agent  VISIT  ENGD_VISIT  \
# 0  MOZILLA/5.0 (IPHONE; CPU IPHONE OS 12_1_4 LIKE...      2           0
# 1  MOZILLA/5.0 (IPHONE; CPU IPHONE OS 12_1_4 LIKE...      1           0
# 2  MOZILLA/5.0 (LINUX; ANDROID 9; SOV36) APPLEWEB...      2           1
# 3  MOZILLA/5.0 (LINUX; ANDROID 7.0; 5026D) APPLEW...      1           0
# 4  MOZILLA/5.0 (WINDOWS NT 6.1; WIN64; X64) APPLE...      1           0
#
#    VIEWS                                           page_url  wk  mth    yr
# 0      9  www.ustream.tv/channel/%e3%82%a4%e3%82%b1-%e3%...   9    3  2019
# 1      1                  www.ibm.com/products/spss-modeler   9    3  2019
# 2      3  www.ibm.com/support/knowledgecenter/ja/sstrgz_...   9    3  2019
# 3      1             www.ibm.com/uk-en/cloud/aspera/pricing   9    3  2019
# 4      1  www.ibm.com/support/knowledgecenter/en/ssvrgu_...   9    3  2019

# %%
df.describe()
# Out:
#               VISIT    ENGD_VISIT         VIEWS         wk        mth  \
# count  1.399248e+06  1.399248e+06  1.399248e+06  1399248.0  1399248.0
# mean   1.110384e+00  3.609617e-01  1.431047e+00        9.0        3.0
# std    2.295467e+00  1.088210e+00  4.234820e+00        0.0        0.0
# min    1.000000e+00  0.000000e+00  1.000000e+00        9.0        3.0
# 25%    1.000000e+00  0.000000e+00  1.000000e+00        9.0        3.0
# 50%    1.000000e+00  0.000000e+00  1.000000e+00        9.0        3.0
# 75%    1.000000e+00  1.000000e+00  1.000000e+00        9.0        3.0
# max    7.590000e+02  4.270000e+02  1.914000e+03        9.0        3.0
#
#               yr
# count  1399248.0
# mean      2019.0
# std          0.0
# min       2019.0
# 25%       2019.0
# 50%       2019.0
# 75%       2019.0
# max       2019.0

# %%
df.shape
# Out:
# (1399248, 17)

# %%
df.sample(5)
# Out:
#             ctry_name intgrtd_mngmt_name intgrtd_operating_team_name  \
# 11283          Brazil             Brazil               Latin America
# 899493  United States      United States               North America
# 264712         France             France                      Europe
# 907392  United States      United States               North America
# 406147         Brazil             Brazil               Latin America
#
#                   city              st   sec_lvl_domn  device_type  \
# 11283   HERVAL D'OESTE  SANTA CATARINA   MHNET.COM.BR  MOBILEPHONE
# 899493         CHICAGO        ILLINOIS            NaN          NaN
# 264712           PARIS           PARIS  MICROPOLE.COM          NaN
# 907392        MATTAPAN   MASSACHUSETTS    SPCSDNS.NET  MOBILEPHONE
# 406147       GUARULHOS       SAO PAULO            NaN  MOBILEPHONE
#
#               operating_sys  \
# 11283             ANDROID_9
# 899493  MICROSOFT_WINDOWS10
# 264712  MICROSOFT_WINDOWS10
# 907392        ANDROID_7.1.2
# 406147             IOS_11.4
#
#                                                   ip_addr  \
# 11283   c784580eb391c340775ac9a2398389cdd0579a9654a0ee...
# 899493  9ea67b4ff5fb3c38a1a49290b72f63d2a8be6380f2061a...
# 264712  241b8c0caa01774aedc7f0df31dd7bcedff986ce565412...
# 907392  b3304b196617e94944b4a7cebd2290b083ecffd45c1606...
# 406147  4716a453c7991d8dfc74fa268a2b29657aa6c4b3871438...
#
#                                                user_agent  VISIT  ENGD_VISIT  \
# 11283   MOZILLA/5.0 (LINUX; ANDROID 9; MOTO G(6) PLUS)...      1           0
# 899493  MOZILLA/5.0 (WINDOWS NT 10.0; WOW64; TRIDENT/7...      1           1
# 264712  MOZILLA/5.0 (WINDOWS NT 10.0; WIN64; X64) APPL...      1           0
# 907392  MOZILLA/5.0 (LINUX; ANDROID 7.1.2; LG-SP200) A...      1           0
# 406147  MOZILLA/5.0 (IPHONE; CPU IPHONE OS 11_4 LIKE M...      1           0
#
#         VIEWS                                           page_url  wk  mth  \
# 11283       1  www.ibm.com/support/knowledgecenter/pt-br/sslk...   9    3
# 899493      1  www.ibm.com/support/knowledgecenter/en/ssepek_...   9    3
# 264712      1  www.ibm.com/support/knowledgecenter/en/search/...   9    3
# 907392      1               www.ibm.com/thought-leadership/smart   9    3
# 406147      1                  www.ibm.com/cloud-computing/br/pt   9    3
#
#           yr
# 11283   2019
# 899493  2019
# 264712  2019
# 907392  2019
# 406147  2019

# %%
q=df.query('VISIT == ENGD_VISIT')

# %%
r=df.query('VISIT > ENGD_VISIT')

# %%
q.shape
# Out:
# (441686, 17)

# %%
r.shape
# Out:
# (957562, 17)

# %%
# df.plot(kind='bar',x="VISIT",y="ENGD_VISIT",color='red')
# plt.show()

# %%
df['page_url'].value_counts()[:20].plot(kind='barh')
