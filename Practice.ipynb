# %%
import numpy
import pandas
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense,LSTM
# Out:
# Using TensorFlow backend.
# /anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.6 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.7
#   return f(*args, **kwds)

# %%
#Convert an array of values into a dataset matrix
def dataset_generate(data, step_size=1):
    dataX, dataY = [], []
    for i in range(len(data)- step_size -1):
       a = data[i:(i+ step_size), 0]
       dataX.append(a)
       dataY.append(data[i + step_size, 0])
    return numpy.array(dataX), numpy.array(dataY)
 
#Fix random seed for reproducibility
numpy.random.seed(7)
 
#Load the dataset
dataframe = pandas.read_excel('Data.xlsx', usecols=[0], skipfooter=3)
dataset = dataframe.values
dataset = dataset.astype('float32')
 
#Normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)
 
#Split into train and test sets
train_size = int(len(dataset) * 0.75)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
 
#Reshape into X=t and Y=t+1
step_size = 1
trainX, trainY = dataset_generate(train, step_size)
testX, testY = dataset_generate(test, step_size)
 
#Reshape input to be [samples, time steps, features]
trainX = numpy.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = numpy.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

print(trainX)
print(testX)
# Out:
# [[[0.23531184]]
#
#  [[0.44370794]]
#
#  [[0.30742192]]
#
#  [[0.5115999 ]]
#
#  [[0.36798233]]
#
#  [[0.38736567]]
#
#  [[0.40142614]]
#
#  [[0.3911821 ]]
#
#  [[0.49161392]]
#
#  [[0.6901677 ]]
#
#  [[0.42934617]]
#
#  [[0.5152154 ]]
#
#  [[0.5523752 ]]
#
#  [[0.38385054]]
#
#  [[0.3263031 ]]
#
#  [[0.34980416]]
#
#  [[0.5369087 ]]
#
#  [[0.3931907 ]]
#
#  [[0.4738375 ]]
#
#  [[0.8203274 ]]
#
#  [[0.4961334 ]]
#
#  [[0.38545746]]
#
#  [[0.5046701 ]]
#
#  [[0.4612835 ]]
#
#  [[0.49864417]]
#
#  [[0.48819926]]
#
#  [[0.26052025]]
#
#  [[0.34779552]]
#
#  [[0.47293362]]
#
#  [[0.5486592 ]]
#
#  [[0.39831275]]
#
#  [[0.50969166]]
#
#  [[0.60620666]]
#
#  [[0.38565832]]
#
#  [[0.35100934]]
#
#  [[0.37712163]]
#
#  [[0.54966354]]
#
#  [[0.4961334 ]]
#
#  [[0.47172844]]
#
#  [[0.3880687 ]]
#
#  [[0.4000201 ]]
#
#  [[0.440695  ]]
#
#  [[0.515818  ]]
#
#  [[0.3716983 ]]
#
#  [[0.46921763]]
#
#  [[0.4256302 ]]
#
#  [[0.3237923 ]]
#
#  [[0.449533  ]]
#
#  [[0.5211409 ]]
#
#  [[1.        ]]
#
#  [[0.37882897]]
#
#  [[0.16701818]]
#
#  [[0.        ]]
#
#  [[0.2349101 ]]
#
#  [[0.34096617]]
#
#  [[0.31545645]]
#
#  [[0.3474942 ]]
#
#  [[0.42633322]]
#
#  [[0.47343576]]
#
#  [[0.35603094]]
#
#  [[0.69026816]]
#
#  [[0.5012554 ]]
#
#  [[0.58913326]]
#
#  [[0.40333435]]
#
#  [[0.4819725 ]]
#
#  [[0.40845636]]
#
#  [[0.27789494]]
#
#  [[0.23159584]]
#
#  [[0.40725118]]
#
#  [[0.3786281 ]]
#
#  [[0.29275885]]
#
#  [[0.39228684]]
#
#  [[0.35683438]]
#
#  [[0.30219945]]
#
#  [[0.3559305 ]]]
# [[[0.6755047 ]]
#
#  [[0.5190318 ]]
#
#  [[0.23641658]]
#
#  [[0.35994777]]
#
#  [[0.3773225 ]]
#
#  [[0.37792507]]
#
#  [[0.34819725]]
#
#  [[0.4707241 ]]
#
#  [[0.33082253]]
#
#  [[0.2884403 ]]
#
#  [[0.37902984]]
#
#  [[0.32469618]]
#
#  [[0.45937532]]
#
#  [[0.45756754]]
#
#  [[0.35643265]]
#
#  [[0.26945868]]
#
#  [[0.29125237]]
#
#  [[0.3288139 ]]
#
#  [[0.3117405 ]]
#
#  [[0.29687658]]
#
#  [[0.296977  ]]
#
#  [[0.30983227]]
#
#  [[0.24143817]]
#
#  [[0.31384957]]]

# %%
model = Sequential()
model.add(LSTM(4, input_dim= step_size))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(trainX, trainY, nb_epoch=100, batch_size=1, verbose=2)
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: The `input_dim` and `input_length` arguments in recurrent layers are deprecated. Use `input_shape` instead.
#
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Update your `LSTM` call to the Keras 2 API: `LSTM(4, input_shape=(None, 1))`
#
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   """
# Epoch 1/100
#  - 1s - loss: 0.1506
# Epoch 2/100
#  - 0s - loss: 0.0784
# Epoch 3/100
#  - 0s - loss: 0.0368
# Epoch 4/100
#  - 0s - loss: 0.0208
# Epoch 5/100
#  - 0s - loss: 0.0172
# Epoch 6/100
#  - 0s - loss: 0.0170
# Epoch 7/100
#  - 0s - loss: 0.0171
# Epoch 8/100
#  - 0s - loss: 0.0169
# Epoch 9/100
#  - 0s - loss: 0.0168
# Epoch 10/100
#  - 0s - loss: 0.0169
# Epoch 11/100
#  - 0s - loss: 0.0169
# Epoch 12/100
#  - 0s - loss: 0.0170
# Epoch 13/100
#  - 0s - loss: 0.0168
# Epoch 14/100
#  - 0s - loss: 0.0169
# Epoch 15/100
#  - 0s - loss: 0.0168
# Epoch 16/100
#  - 0s - loss: 0.0169
# Epoch 17/100
#  - 0s - loss: 0.0168
# Epoch 18/100
#  - 0s - loss: 0.0170
# Epoch 19/100
#  - 0s - loss: 0.0171
# Epoch 20/100
#  - 0s - loss: 0.0168
# Epoch 21/100
#  - 0s - loss: 0.0169
# Epoch 22/100
#  - 1s - loss: 0.0169
# Epoch 23/100
#  - 0s - loss: 0.0170
# Epoch 24/100
#  - 0s - loss: 0.0169
# Epoch 25/100
#  - 0s - loss: 0.0169
# Epoch 26/100
#  - 0s - loss: 0.0169
# Epoch 27/100
#  - 0s - loss: 0.0169
# Epoch 28/100
#  - 1s - loss: 0.0169
# Epoch 29/100
#  - 0s - loss: 0.0169
# Epoch 30/100
#  - 0s - loss: 0.0168
# Epoch 31/100
#  - 1s - loss: 0.0169
# Epoch 32/100
#  - 0s - loss: 0.0169
# Epoch 33/100
#  - 0s - loss: 0.0171
# Epoch 34/100
#  - 0s - loss: 0.0169
# Epoch 35/100
#  - 0s - loss: 0.0169
# Epoch 36/100
#  - 0s - loss: 0.0169
# Epoch 37/100
#  - 0s - loss: 0.0168
# Epoch 38/100
#  - 0s - loss: 0.0170
# Epoch 39/100
#  - 0s - loss: 0.0170
# Epoch 40/100
#  - 0s - loss: 0.0169
# Epoch 41/100
#  - 0s - loss: 0.0168
# Epoch 42/100
#  - 0s - loss: 0.0168
# Epoch 43/100
#  - 0s - loss: 0.0168
# Epoch 44/100
#  - 0s - loss: 0.0169
# Epoch 45/100
#  - 0s - loss: 0.0167
# Epoch 46/100
#  - 0s - loss: 0.0169
# Epoch 47/100
#  - 0s - loss: 0.0168
# Epoch 48/100
#  - 0s - loss: 0.0169
# Epoch 49/100
#  - 0s - loss: 0.0168
# Epoch 50/100
#  - 0s - loss: 0.0169
# Epoch 51/100
#  - 0s - loss: 0.0169
# Epoch 52/100
#  - 0s - loss: 0.0169
# Epoch 53/100
#  - 0s - loss: 0.0168
# Epoch 54/100
#  - 0s - loss: 0.0168
# Epoch 55/100
#  - 0s - loss: 0.0172
# Epoch 56/100
#  - 0s - loss: 0.0167
# Epoch 57/100
#  - 0s - loss: 0.0169
# Epoch 58/100
#  - 0s - loss: 0.0168
# Epoch 59/100
#  - 0s - loss: 0.0169
# Epoch 60/100
#  - 0s - loss: 0.0169
# Epoch 61/100
#  - 0s - loss: 0.0169
# Epoch 62/100
#  - 0s - loss: 0.0167
# Epoch 63/100
#  - 0s - loss: 0.0170
# Epoch 64/100
#  - 0s - loss: 0.0170
# Epoch 65/100
#  - 0s - loss: 0.0167
# Epoch 66/100
#  - 0s - loss: 0.0169
# Epoch 67/100
#  - 0s - loss: 0.0170
# Epoch 68/100
#  - 0s - loss: 0.0168
# Epoch 69/100
#  - 0s - loss: 0.0169
# Epoch 70/100
#  - 0s - loss: 0.0167
# Epoch 71/100
#  - 0s - loss: 0.0168
# Epoch 72/100
#  - 0s - loss: 0.0168
# Epoch 73/100
#  - 0s - loss: 0.0169
# Epoch 74/100
#  - 0s - loss: 0.0167
# Epoch 75/100
#  - 0s - loss: 0.0167
# Epoch 76/100
#  - 0s - loss: 0.0170
# Epoch 77/100
#  - 0s - loss: 0.0168
# Epoch 78/100
#  - 0s - loss: 0.0168
# Epoch 79/100
#  - 0s - loss: 0.0167
# Epoch 80/100
#  - 0s - loss: 0.0167
# Epoch 81/100
#  - 0s - loss: 0.0167
# Epoch 82/100
#  - 0s - loss: 0.0169
# Epoch 83/100
#  - 0s - loss: 0.0169
# Epoch 84/100
#  - 0s - loss: 0.0167
# Epoch 85/100
#  - 0s - loss: 0.0169
# Epoch 86/100
#  - 0s - loss: 0.0168
# Epoch 87/100
#  - 0s - loss: 0.0170
# Epoch 88/100
#  - 0s - loss: 0.0168
# Epoch 89/100
#  - 0s - loss: 0.0171
# Epoch 90/100
#  - 0s - loss: 0.0166
# Epoch 91/100
#  - 0s - loss: 0.0168
# Epoch 92/100
#  - 0s - loss: 0.0167
# Epoch 93/100
#  - 0s - loss: 0.0168
# Epoch 94/100
#  - 0s - loss: 0.0166
# Epoch 95/100
#  - 0s - loss: 0.0167
# Epoch 96/100
#  - 0s - loss: 0.0171
# Epoch 97/100
#  - 0s - loss: 0.0167
# Epoch 98/100
#  - 0s - loss: 0.0167
# Epoch 99/100
#  - 0s - loss: 0.0168
# Epoch 100/100
#  - 0s - loss: 0.0168

# %%
trainPredict = model.predict(trainX)
 
testPredict = []
 
input = trainY[-1]
temp = [[input]]
predX = [temp]
 
a = model.predict(numpy.array(predX))
b = a.tolist ()
predX = [b]
testPredict.append(b[0])

# %%
for i in range(test_size - 3):
    print ('Iteration %d: Done' % i)
    trainX = numpy.concatenate([trainX, [b]])
    trainY = numpy.concatenate ([trainY, b[0]])
    model.fit (trainX, trainY, nb_epoch=10, batch_size=1, verbose=2)
    a = model.predict (numpy.array ([b]))
    b = a.tolist ()
    testPredict.append (b[0])
    print ('Prediction %d:'%i, b)
testPredict = numpy.array(testPredict)
# Out:
# Iteration 0: Done
# Epoch 1/10
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   """
#  - 0s - loss: 0.0117
# Epoch 2/10
#  - 0s - loss: 0.0117
# Epoch 3/10
#  - 0s - loss: 0.0118
# Epoch 4/10
#  - 0s - loss: 0.0117
# Epoch 5/10
#  - 0s - loss: 0.0117
# Epoch 6/10
#  - 0s - loss: 0.0117
# Epoch 7/10
#  - 0s - loss: 0.0117
# Epoch 8/10
#  - 0s - loss: 0.0117
# Epoch 9/10
#  - 0s - loss: 0.0116
# Epoch 10/10
#  - 0s - loss: 0.0118
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-e60f61a7c45e> in <module>
#       6     a = model.predict (numpy.array ([b]))
#       7     b = a.tolist ()
# ----> 8     testPredict.append (b[0])
#       9     print ('Prediction %d:'%i, b)
#      10 testPredict = numpy.array(testPredict)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'append'
