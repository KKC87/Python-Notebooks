# %%
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
import warnings
import itertools
import numpy as np

import pandas as pd
import statsmodels.api as sm

# %%
df=pd.read_csv('Data1.csv')

# %%
fd=df[(df['OFFRNG_ID']==178)  & (df['GEO_ID']==224)]

# %%
#df['MonthYear'] = pd.to_datetime(df[['YEAR', 'MONTH']].assign(Day=1)).dt.strftime('%Y-%m')

# %%
df
# Out:
#         DATE_KEY  OFFRNG_ID  GEO_ID  NO_OF_OPRTNTY_CREATD  NO_OF_WINS  \
# 0          42901        194      15                     1           1
# 1          42901        194      46                     1           0
# 2          42901        194     224                     0           1
# 3          42901        194      46                     1           0
# 4          42901        194     224                     0           1
# 5          42901        194      71                     1           0
# 6          42901        194     166                     1           0
# 7          42901        194     223                     0           2
# 8          42901        194     103                     0           1
# 9          42901        194      31                     0           1
# 10         42901        194      71                     1           0
# 11         42901        192     106                     1           0
# ...

# %%
#df=df.sort_values(by=['MonthYear'])

# %%
#df

# %%
df=df.drop('DATE_KEY',axis=1)

# %%
df=df.drop('OFFRNG_ID',axis=1)

# %%
df=df.drop('GEO_ID',axis=1)

# %%
#df=df.drop('NO_OF_WINS',axis=1)

# %%
df
# Out:
#         NO_OF_OPRTNTY_CREATD  NO_OF_WINS        DATE
# 0                          1           1  2017-06-15
# 1                          1           0  2017-06-15
# 2                          0           1  2017-06-15
# 3                          1           0  2017-06-15
# 4                          0           1  2017-06-15
# 5                          1           0  2017-06-15
# 6                          1           0  2017-06-15
# 7                          0           2  2017-06-15
# 8                          0           1  2017-06-15
# 9                          0           1  2017-06-15
# 10                         1           0  2017-06-15
# 11                         1           0  2017-06-15
# 12                         2           0  2017-06-15
# 13                         0           1  2017-06-15
# 14                         0           1  2017-06-15
# 15                         1           0  2017-06-19
# 16                         0           1  2017-06-15
# ...

# %%
fd.dtypes
# Out:
# DATE_KEY                 int64
# OFFRNG_ID                int64
# GEO_ID                   int64
# NO_OF_OPRTNTY_CREATD     int64
# NO_OF_WINS               int64
# DATE                    object
# dtype: object

# %%
# fd=fd.drop('DATE_KEY',axis=1)
# fd=fd.drop('OFFRNG_ID',axis=1)
# fd=fd.drop('GEO_ID',axis=1)

# %%
df['DATE'] = pd.to_datetime(df['DATE'], errors='coerce')

# %%
per = df.DATE.dt.to_period("M")  # new way to get the same

# %%
data = df.groupby(per)

# %%
data=data.sum()

# %%
data
# Out:
#          NO_OF_OPRTNTY_CREATD  NO_OF_WINS
# DATE
# 2016-12                    29         307
# 2017-01                  7061        1709
# 2017-02                  7979        1382
# 2017-03                  6127        1800
# 2017-04                  1728         927
# 2017-05                 11043        2118
# 2017-06                  9051        2666
# 2017-07                 10084        2552
# 2017-08                 11309        2509
# 2017-09                  7583        1795
# 2017-10                  8996        1497
# 2017-11                 11193        2379
# 2017-12                  9477        4878
# 2018-01                  8322        1672
# 2018-02                  9386        1619
# 2018-03                 10299        4774
# 2018-04                  7207        2175
# 2018-05                  9228        2108
# 2018-06                  7756        1961
# 2018-07                  7998        1645
# 2018-08                  9140        2033
# ...

# %%
data.index
# Out:
# PeriodIndex(['2016-12', '2017-01', '2017-02', '2017-03', '2017-04', '2017-05',
#              '2017-06', '2017-07', '2017-08', '2017-09', '2017-10', '2017-11',
#              '2017-12', '2018-01', '2018-02', '2018-03', '2018-04', '2018-05',
#              '2018-06', '2018-07', '2018-08', '2018-09', '2018-10', '2018-11',
#              '2018-12', '2019-01', '2019-02'],
#             dtype='period[M]', name='DATE', freq='M')

# %%
data = data.ix[1:]
data = data.ix[:-2]
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated

# %%
#data=data.drop('NO_OF_OPRTNTY_CREATD',axis=1)

# %%
data
# Out:
#          NO_OF_OPRTNTY_CREATD  NO_OF_WINS
# DATE
# 2017-02                  7979        1382
# 2017-03                  6127        1800
# 2017-04                  1728         927
# 2017-05                 11043        2118
# 2017-06                  9051        2666
# 2017-07                 10084        2552
# 2017-08                 11309        2509
# 2017-09                  7583        1795
# 2017-10                  8996        1497
# 2017-11                 11193        2379
# 2017-12                  9477        4878
# 2018-01                  8322        1672
# 2018-02                  9386        1619
# 2018-03                 10299        4774
# 2018-04                  7207        2175
# 2018-05                  9228        2108
# 2018-06                  7756        1961
# 2018-07                  7998        1645
# 2018-08                  9140        2033
# 2018-09                  7368        2549
# 2018-10                  4147        1038

# %%
data.index
# Out:
# PeriodIndex(['2017-01', '2017-02', '2017-03', '2017-04', '2017-05', '2017-06',
#              '2017-07', '2017-08', '2017-09', '2017-10', '2017-11', '2017-12',
#              '2018-01', '2018-02', '2018-03', '2018-04', '2018-05', '2018-06',
#              '2018-07', '2018-08', '2018-09', '2018-10', '2018-11', '2018-12'],
#             dtype='period[M]', name='DATE', freq='M')

# %%
import warnings
import itertools
import numpy as np
#import matplotlib.pyplot as plt

#plt.style.use('fivethirtyeight')
import pandas as pd
import statsmodels.api as sm

#plt.rcParams['axes.labelsize'] = 14
#plt.rcParams['xtick.labelsize'] = 12
#plt.rcParams['ytick.labelsize'] = 12
#plt.rcParams['text.color'] = 'k'

# %%
p = d = q = range(0, 2)
pdq = list(itertools.product(p, d, q))
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in pdq]
print('Examples of parameter combinations for Seasonal ARIMA...')
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[1]))
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[2]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[3]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[4]))
# Out:
# Examples of parameter combinations for Seasonal ARIMA...
# SARIMAX: (0, 0, 1) x (0, 0, 1, 12)
# SARIMAX: (0, 0, 1) x (0, 1, 0, 12)
# SARIMAX: (0, 1, 0) x (0, 1, 1, 12)
# SARIMAX: (0, 1, 0) x (1, 0, 0, 12)

# %%
for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            mod = sm.tsa.statespace.SARIMAX(data,
                                            order=param,
                                            seasonal_order=param_seasonal,
                                            enforce_stationarity=False,
                                            enforce_invertibility=False)
            results = mod.fit()
            print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))
        except:
            continue

# %%
import statsmodels.api as sm
mod = sm.tsa.statespace.SARIMAX(data,
                                order=(0, 1, 1),
                                seasonal_order=(0, 1, 0, 12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)
results = mod.fit()
print(results.summary().tables[1])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-92-3f353c984c9e> in <module>
#       4                                 seasonal_order=(0, 1, 0, 12),
#       5                                 enforce_stationarity=False,
# ----> 6                                 enforce_invertibility=False)
#       7 results = mod.fit()
#       8 print(results.summary().tables[1])
#
# /anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py in __init__(self, endog, exog, order, seasonal_order, trend, measurement_error, time_varying_regression, mle_regression, simple_differencing, enforce_stationarity, enforce_invertibility, hamilton_representation, **kwargs)
#     509
#     510         # Initialize the fixed components of the statespace model
# --> 511         self.ssm['design'] = self.initial_design
# ...

# %%
pred = results.get_prediction(start=pd.to_datetime('2018-01-01'), dynamic=False)
pred_ci = pred.conf_int()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-64-4e70d860ef59> in <module>
# ----> 1 pred = results.get_prediction(start=pd.to_datetime('2018-01-01'), dynamic=False)
#       2 pred_ci = pred.conf_int()
#
# NameError: name 'results' is not defined

# %%
pred.predicted_mean.index
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-76f0d570e26d> in <module>
# ----> 1 pred.predicted_mean.index
#
# NameError: name 'pred' is not defined

# %%
pred_uc = results.get_forecast(steps=3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-182311a71bc1> in <module>
# ----> 1 pred_uc = results.get_forecast(steps=3)
#       2
#
# NameError: name 'results' is not defined

# %%
pred_uc.predicted_mean
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-1c74084a276b> in <module>
# ----> 1 pred_uc.predicted_mean
#
# NameError: name 'pred_uc' is not defined

# %%
x=pred_uc.predicted_mean
y=data[:-2]
plt.plot(x, y)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-de145ec0d2bf> in <module>
# ----> 1 x=pred_uc.predicted_mean
#       2 y=data[:-2]
#       3 plt.plot(x, y)
#       4 plt.show()
#
# NameError: name 'pred_uc' is not defined

# %%
#converting dict to dataframe
#dict={"0": {"LEADS": 2, "MONTH": 3, "WINS": 0, "YEAR": 2017}, "1": {"LEADS": 1, "MONTH": 4, "WINS": 0, "YEAR": 2017}, "2": {"LEADS": 2, "MONTH": 6, "WINS": 0, "YEAR": 2017}, "3": {"LEADS": 6, "MONTH": 7, "WINS": 0, "YEAR": 2017}, "4": {"LEADS": 3, "MONTH": 8, "WINS": 0, "YEAR": 2017}, "5": {"LEADS": 5, "MONTH": 9, "WINS": 0, "YEAR": 2017}, "6": {"LEADS": 5, "MONTH": 10, "WINS": 0, "YEAR": 2017}, "7": {"LEADS": 4, "MONTH": 11, "WINS": 1, "YEAR": 2017}, "8": {"LEADS": 1, "MONTH": 12, "WINS": 1, "YEAR": 2017}, "9": {"LEADS": 2, "MONTH": 1, "WINS": 0, "YEAR": 2018}, "10": {"LEADS": 6, "MONTH": 2, "WINS": 0, "YEAR": 2018}, "11": {"LEADS": 4, "MONTH": 3, "WINS": 0, "YEAR": 2018}, "12": {"LEADS": 7, "MONTH": 4, "WINS": 1, "YEAR": 2018}, "13": {"LEADS": 7, "MONTH": 5, "WINS": 1, "YEAR": 2018}, "14": {"LEADS": 1, "MONTH": 6, "WINS": 0, "YEAR": 2018}, "15": {"LEADS": 1, "MONTH": 7, "WINS": 1, "YEAR": 2018}, "16": {"LEADS": 3, "MONTH": 8, "WINS": 0, "YEAR": 2018}, "17": {"LEADS": 5, "MONTH": 9, "WINS": 0, "YEAR": 2018}, "18": {"LEADS": 2, "MONTH": 11, "WINS": 0, "YEAR": 2018}, "19": {"LEADS": 0, "MONTH": 12, "WINS": 3, "YEAR": 2018}, "20": {"LEADS": 2, "MONTH": 1, "WINS": 0, "YEAR": 2019}, "21": {"LEADS": 3, "MONTH": 2, "WINS": 0, "YEAR": 2019}}

# %%
#x=pd.DataFrame.from_dict(dict,orient='index')

# %%
#import datetime as dt

# %%
#x['MonthYear'] = pd.to_datetime(x[['YEAR', 'MONTH']].assign(Day=1)).dt.strftime('%Y-%m')

# %%
#x=x.sort_values(by=['MonthYear'])

# %%
# x=x.drop('WINS',axis=1)
# x=x.drop('YEAR',axis=1)
# x=x.drop('MONTH',axis=1)

# %%
# x=x.set_index('MonthYear')
